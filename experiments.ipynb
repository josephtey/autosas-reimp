# %%
import pickle

with open('data/asap_02/splits/cv1.pkl', 'rb') as file:
    data = pickle.load(file)

print(data)
# Out:
# {'train': array(['2789', '2790', '2791', ..., '4063', '4064', '4065'], dtype=object), 'valid': array(['2788', '2794', '2799', '2810', '2824', '2833', '2836', '2847',
#        '2857', '2860', '2865', '2866', '2876', '2877', '2889', '2894',
#        '2895', '2898', '2899', '2900', '2906', '2908', '2912', '2918',
#        '2920', '2931', '2935', '2936', '2937', '2939', '2951', '2964',
#        '2980', '2981', '3008', '3015', '3017', '3019', '3021', '3022',
#        '3023', '3028', '3035', '3047', '3054', '3056', '3057', '3059',
#        '3060', '3064', '3068', '3071', '3072', '3078', '3085', '3090',
#        '3093', '3098', '3099', '3113', '3115', '3119', '3128', '3133',
#        '3151', '3155', '3160', '3161', '3162', '3165', '3171', '3186',
#        '3189', '3205', '3216', '3217', '3218', '3219', '3224', '3227',
#        '3230', '3232', '3234', '3236', '3237', '3240', '3242', '3244',
#        '3245', '3248', '3250', '3251', '3252', '3253', '3256', '3258',
# ...

# %%
from utils.auto_sas import AutoSAS
import pandas as pd

# %load_ext autoreload
# %autoreload 2


with open('output/20240710_012213_autosas/dataset_with_features.pkl', 'rb') as dataset_file:
    dataset = pickle.load(dataset_file)

with open('data/asap_01/splits/cv1.pkl', 'rb') as split_file:
    splits = pickle.load(split_file)

with open('output/20240710_012213_autosas/1_best_model.pkl', 'rb') as model_file:
    best_model = pickle.load(model_file)

with open('output/20240710_012213_autosas/1_scaler.pkl', 'rb') as scaler_file:
    scaler = pickle.load(scaler_file)

auto_sas = AutoSAS(1, dataset, splits, scaler, best_model)

auto_sas.evaluate_model()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Evaluation on Test Set:
# Cohen Kappa Score (Weighted): 0.6659453725162818
# Accuracy: 0.533213644524237
# Confusion Matrix:
# [[ 91   8   4   0]
#  [ 51  55  56   6]
#  [ 12  21 109  33]
#  [  6   8  55  42]]
